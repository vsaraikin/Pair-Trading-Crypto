# %% [markdown]
# ### Here are the best performed parameters

# %%
import pandas as pd
r = pd.read_csv('log.txt')

# %%
r.sort_values(by=' returns', ascending=False).head(50)
# Out:
#       ticker1  ticker2   zscore   profit_cash   returns   trades   sma_short  \
# 2143  BNBUSDT  EOSUSDT      0.5   1172.606408   3157.49     7167          45
# 2144  BNBUSDT  EOSUSDT      0.6   1166.106410   3139.99     6608          45
# 1607  BNBUSDT  LTCUSDT      0.5   1155.923861   3090.64     7034          45
# 2158  BNBUSDT  EOSUSDT      0.5   1135.494012   3044.06     6617          50
# 2173  BNBUSDT  EOSUSDT      0.5   1096.244758   2935.37     6141          55
# 2145  BNBUSDT  EOSUSDT      0.7   1089.397326   2933.43     6113          45
# 1622  BNBUSDT  LTCUSDT      0.5   1089.525117   2913.11     6541          50
# 2174  BNBUSDT  EOSUSDT      0.6   1086.607921   2909.56     5657          55
# 1608  BNBUSDT  LTCUSDT      0.6   1085.126867   2901.35     6486          45
# 2159  BNBUSDT  EOSUSDT      0.6   1059.951652   2841.55     6055          50
# 2160  BNBUSDT  EOSUSDT      0.7   1059.817184   2841.19     5586          50
# ...
